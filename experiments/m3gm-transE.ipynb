# %%
# !sudo add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !sudo apt-get update -qq 2>&1 > /dev/null
# !sudo apt -y install -qq google-drive-ocamlfuse 2>&1 > /dev/null
# !google-drive-ocamlfuse
# Out:
# W: GPG error: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY A4B469963BF863CC
# E: The repository 'https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease' is no longer signed.
# W: GPG error: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY A4B469963BF863CC
# E: The repository 'https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease' is no longer signed.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=EqwLPDs7tZ3DpBvItsRsUJKzqgGYcEfkolzALhd88oo'
# /bin/sh: 1: firefox: not found
# /bin/sh: 1: google-chrome: not found
# /bin/sh: 1: chromium-browser: not found
# /bin/sh: 1: open: not found
# Cannot retrieve auth tokens.
# Failure("Error opening URL:https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=EqwLPDs7tZ3DpBvItsRsUJKzqgGYcEfkolzALhd88oo")

# %%
# !sudo apt-get install -qq w3m # to act as web browser 
# !xdg-settings set default-web-browser w3m.desktop # to set default browser
# %cd /content
# !mkdir drive
# %cd drive
# !mkdir MyDrive
# %cd ..
# %cd ..
# !google-drive-ocamlfuse /content/drive/MyDrive
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgpm2:amd64.
# (Reading database ... 155519 files and directories currently installed.)
# Preparing to unpack .../libgpm2_1.20.7-5_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.7-5) ...
# Selecting previously unselected package w3m.
# Preparing to unpack .../w3m_0.5.3-36build1_amd64.deb ...
# Unpacking w3m (0.5.3-36build1) ...
# Setting up libgpm2:amd64 (1.20.7-5) ...
# Setting up w3m (0.5.3-36build1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# /content
# /content/drive
# /content
# /
# Access token retrieved correctly.

# %% [markdown]
# ## Dependencies

# %%
# !pip install dynet
# !pip show dynet
# Out:
# Collecting dynet
#   Downloading dyNET-2.1.2-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 13.8 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from dynet) (0.29.28)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dynet) (1.21.6)
# Installing collected packages: dynet
# Successfully installed dynet-2.1.2
# Name: dyNET
# Version: 2.1.2
# Summary: The Dynamic Neural Network Toolkit
# Home-page: https://github.com/clab/dynet
# Author: Graham Neubig
# Author-email: dynet-users@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: numpy, cython
# Required-by:

# %%
# %cd /content/drive/MyDrive/10708/m3gm-master
# !python create_wn18_data.py --base-dir /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text
# Out:
# /content/drive/MyDrive/10708/m3gm-master
# read 86834 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/train.txt, now have 40714 synsets
# read 3033 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/valid.txt, now have 40919 synsets
# read 3133 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/test.txt, now have 41105 synsets
# all relations:  {'instance_hypernym', 'hypernym', 'verb_group', 'derivationally_related_form', 'similar_to', 'member_of_domain_usage', 'also_see', 'member_meronym', 'member_of_domain_region', 'has_part', 'synset_domain_topic_of'}
# node count:  41105
# first sorted synsets:  ['land_reform.n.01', 'reform.n.01', 'cover.v.01', 'covering.n.02', 'botany.n.02', 'botanize.v.01', 'kamet.n.01', 'mountain_peak.n.01', 'question.n.01', 'ask.v.01']
# last sorted synsets:  ['fire.v.06', 'parade.n.03', 'grey_matter.n.01', 'clinton.n.02', 'hamstring.v.01', 'holly-leaved_cherry.n.01', 'warwick.n.01', 'iconoclast.n.01', 'electrocution.n.01', 'accentor.n.01']
# creating matrices for relations in train set
# created matrix for relation instance_hypernym
# sample: queen_maud_land.n.01->['geographical_area.n.01']
# created matrix for relation hypernym
# sample: artamidae.n.01->['bird_family.n.01']
# created matrix for relation verb_group
# sample: deem.v.01->['hold.v.16']
# created matrix for relation derivationally_related_form
# sample: kind.n.01->['classify.v.01']
# created matrix for relation similar_to
# sample: advantageous.a.01->['discriminatory.s.04']
# created matrix for relation member_of_domain_usage
# sample: superlative.n.01->['best.a.01', 'worst.a.01']
# created matrix for relation also_see
# sample: amicable.a.01->['lovable.a.01', 'friendly.a.01', 'peaceful.a.01']
# created matrix for relation member_meronym
# sample: genus_oxalis.n.01->['oxalis.n.01']
# created matrix for relation member_of_domain_region
# sample: libya.n.01->['fatah_revolutionary_council.n.01']
# created matrix for relation has_part
# sample: romania.n.01->['carpathians.n.01', 'danube.n.01', 'transylvanian_alps.n.01', 'bucharest.n.01', 'constantina.n.01', 'brasov.n.01']
# created matrix for relation synset_domain_topic_of
# sample: retreat.n.04->['military.n.01']
# creating matrices for relations in dev set
# created matrix for relation instance_hypernym
# sample: mark.n.08->['evangelist.n.02']
# created matrix for relation hypernym
# sample: cypriniformes.n.01->['animal_order.n.01']
# created matrix for relation verb_group
# sample: vascularize.v.01->['vascularize.v.02']
# created matrix for relation derivationally_related_form
# sample: dine.v.01->['diner.n.03']
# created matrix for relation similar_to
# sample: hot.a.03->['sensual.s.02']
# created matrix for relation member_of_domain_usage
# sample: disparagement.n.01->['darky.n.01', 'suit.n.03']
# created matrix for relation also_see
# sample: unhappy.a.01->['joyless.a.01']
# created matrix for relation member_meronym
# sample: labridae.n.01->['tautoga.n.01']
# created matrix for relation member_of_domain_region
# sample: france.n.01->['first_estate.n.01']
# created matrix for relation has_part
# sample: umbrella.n.01->['gore.n.03']
# created matrix for relation synset_domain_topic_of
# sample: expansion.n.02->['mathematics.n.01']
# creating matrices for relations in test set
# created matrix for relation instance_hypernym
# sample: hizb_ut-tahrir.n.01->['terrorist_organization.n.01']
# created matrix for relation hypernym
# sample: burial_chamber.n.01->['chamber.n.01']
# created matrix for relation verb_group
# sample: cuddle.v.01->['nestle.v.03']
# created matrix for relation derivationally_related_form
# sample: ravel.v.01->['run.n.13', 'disentangler.n.01']
# created matrix for relation similar_to
# sample: clean.a.01->['dry-cleaned.s.01']
# created matrix for relation member_of_domain_usage
# sample: united_kingdom.n.01->['chilly.s.02']
# created matrix for relation also_see
# sample: provocative.a.01->['exciting.a.01']
# created matrix for relation member_meronym
# sample: morchellaceae.n.01->['black_morel.n.01']
# created matrix for relation member_of_domain_region
# sample: ardennes.n.01->['battle_of_the_ardennes_bulge.n.01']
# created matrix for relation has_part
# sample: epithelium.n.01->['epithelial_cell.n.01']
# created matrix for relation synset_domain_topic_of
# sample: iseult.n.01->['middle_ages.n.01']
# saving dataset
# done!

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# %cd /content/drive/MyDrive/10708/m3gm-master/data
# !python embed_from_words.py wiki-news-300d-1M.vec ft-embs-all-lower.vec
# Out:
# 2022-03-13 19:20:50.184081	read 117659 synsets
# 2022-03-13 19:20:50.184156	preparing target word dataset
# 100% 117659/117659 [00:00<00:00, 483892.35it/s]
# 2022-03-13 19:20:50.429026	reading input file
# tcmalloc: large alloc 2259091456 bytes == 0x5564e0408000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db54ed17 0x5564db6ce1f5 0x5564db6688f8 0x5564db5525d2 0x5564db63197e 0x5564db552229 0x5564db644b3d 0x5564db5c6458 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 2259091456 bytes == 0x556566e78000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db599b6c 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 4518182912 bytes == 0x5565ed8e8000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db59b9e6 0x5564db59b6c8 0x5564db5a8bdf 0x5564db59a1eb 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 9036357632 bytes == 0x5566fb5c8000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db59b945 0x5564db59b6c8 0x5564db5a8bdf 0x5564db59a1eb 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# ^C

# %%
# !python pretrain_assoc.py --input data/sparse_wn18_matrices.pkl --embeddings data/ft-embs-all-lower.vec --model-out models/pret_transE --nll --assoc-mode transE --neg-samp 10 --early-stopping --eval-dev
# Out:
# [dynet] random seed: 2041589553
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# 2022-04-29 00:53:30.447133	graphs file = data/sparse_wn18_matrices.pkl
# 2022-04-29 00:53:30.447201	embeddings file = data/ft-embs-all-lower.vec
# 2022-04-29 00:53:30.447237	association mode = transE
# 2022-04-29 00:53:30.447263	negative samples = 10
# 2022-04-29 00:53:30.447282	model file = models/pret_transE
# 2022-04-29 00:53:30.447296	using negative log likelihood loss
# 2022-04-29 00:53:30.447309	employing early stopping (over last 2 epochs)
# 2022-04-29 00:53:30.447328	dropout = 0.0
# 2022-04-29 00:53:30.447354	max epochs = 20
# 2022-04-29 00:53:30.447364	Adagrad learning rate = 0.01
# 2022-04-29 00:53:30.447377	rand-nodes = True
# 2022-04-29 00:53:30.447388	overriding symmetric relations with rule-based system
# 2022-04-29 00:53:30.447400	evaluating dev set
# 2022-04-29 00:53:30.492708	loading embeddings...
# 2022-04-29 00:53:45.365324	finished initialization for association model.
# 2022-04-29 00:53:46.826618	starting epoch 1
# 2022-04-29 00:53:46.826730	starting loop over member_of_domain_region
#   0% 0/41105 [00:00<?, ?it/s]The dy.parameter(...) call is now DEPRECATED.
#         There is no longer need to explicitly add parameters to the computation graph.
#         Any used parameter will be added automatically.
# 100% 41105/41105 [01:34<00:00, 436.56it/s]
# 2022-04-29 00:55:20.993731	starting loop over similar_to
# 2022-04-29 00:55:20.993750	RELATION OVERRIDEN
# 2022-04-29 00:55:20.993763	starting loop over hypernym
# 100% 41105/41105 [46:48<00:00, 14.63it/s]
# 2022-04-29 01:42:09.777832	starting loop over has_part
# 100% 41105/41105 [06:55<00:00, 98.94it/s]
# 2022-04-29 01:49:05.217127	starting loop over instance_hypernym
# 100% 41105/41105 [04:07<00:00, 165.95it/s]
# 2022-04-29 01:53:12.914926	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:06<00:00, 622.52it/s]
# 2022-04-29 01:54:18.949516	starting loop over member_meronym
# 100% 41105/41105 [09:54<00:00, 69.15it/s]
# 2022-04-29 02:04:13.399907	starting loop over also_see
# 2022-04-29 02:04:13.399940	RELATION OVERRIDEN
# 2022-04-29 02:04:13.399958	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:20<00:00, 157.56it/s]
# 2022-04-29 02:08:34.294538	starting loop over derivationally_related_form
# 2022-04-29 02:08:34.294558	RELATION OVERRIDEN
# 2022-04-29 02:08:34.294571	starting loop over verb_group
# 2022-04-29 02:08:34.294605	RELATION OVERRIDEN
# 2022-04-29 02:08:34.295739	evaluating after epoch 1
# 2022-04-29 02:17:18.351950	mrr: 0.4191, h@10: 0.4832, h@1: 0.3884
# 2022-04-29 02:17:18.352031	saving trained model to models/pret_transE-ep-01.dyn
# 2022-04-29 02:17:45.076012	starting epoch 2
# 2022-04-29 02:17:45.076127	starting loop over also_see
# 2022-04-29 02:17:45.076142	RELATION OVERRIDEN
# 2022-04-29 02:17:45.076165	starting loop over hypernym
# 100% 41105/41105 [44:03<00:00, 15.55it/s]
# 2022-04-29 03:01:48.322296	starting loop over verb_group
# 2022-04-29 03:01:48.322327	RELATION OVERRIDEN
# 2022-04-29 03:01:48.322339	starting loop over derivationally_related_form
# 2022-04-29 03:01:48.322356	RELATION OVERRIDEN
# 2022-04-29 03:01:48.322363	starting loop over member_of_domain_region
# 100% 41105/41105 [01:25<00:00, 480.89it/s]
# 2022-04-29 03:03:13.803838	starting loop over similar_to
# 2022-04-29 03:03:13.803871	RELATION OVERRIDEN
# 2022-04-29 03:03:13.803880	starting loop over has_part
# 100% 41105/41105 [06:30<00:00, 105.37it/s]
# 2022-04-29 03:09:43.894222	starting loop over instance_hypernym
# 100% 41105/41105 [03:57<00:00, 172.81it/s]
# 2022-04-29 03:13:41.756788	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:13<00:00, 162.20it/s]
# 2022-04-29 03:17:55.181050	starting loop over member_meronym
# 100% 41105/41105 [09:49<00:00, 69.78it/s]
# 2022-04-29 03:27:44.242607	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:03<00:00, 647.11it/s]
# 2022-04-29 03:28:47.768399	evaluating after epoch 2
# 2022-04-29 03:37:30.987245	mrr: 0.4211, h@10: 0.4885, h@1: 0.3891
# 2022-04-29 03:37:30.987398	saving trained model to models/pret_transE-ep-02.dyn
# 2022-04-29 03:37:56.514426	starting epoch 3
# 2022-04-29 03:37:56.514531	starting loop over hypernym
# 100% 41105/41105 [44:18<00:00, 15.46it/s]
# 2022-04-29 04:22:14.688339	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:15<00:00, 160.90it/s]
# 2022-04-29 04:26:30.154145	starting loop over member_meronym
# 100% 41105/41105 [09:53<00:00, 69.31it/s]
# 2022-04-29 04:36:23.206120	starting loop over has_part
# 100% 41105/41105 [06:35<00:00, 103.91it/s]
# 2022-04-29 04:42:58.798436	starting loop over member_of_domain_region
# 100% 41105/41105 [01:27<00:00, 470.55it/s]
# 2022-04-29 04:44:26.159332	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:03<00:00, 646.71it/s]
# 2022-04-29 04:45:29.724599	starting loop over derivationally_related_form
# 2022-04-29 04:45:29.724626	RELATION OVERRIDEN
# 2022-04-29 04:45:29.724640	starting loop over verb_group
# 2022-04-29 04:45:29.724671	RELATION OVERRIDEN
# 2022-04-29 04:45:29.724699	starting loop over also_see
# 2022-04-29 04:45:29.724710	RELATION OVERRIDEN
# 2022-04-29 04:45:29.724721	starting loop over instance_hypernym
# 100% 41105/41105 [04:02<00:00, 169.60it/s]
# 2022-04-29 04:49:32.100624	starting loop over similar_to
# 2022-04-29 04:49:32.100654	RELATION OVERRIDEN
# 2022-04-29 04:49:32.101955	evaluating after epoch 3
# 2022-04-29 04:58:14.705423	mrr: 0.4229, h@10: 0.4914, h@1: 0.3906
# 2022-04-29 04:58:14.705606	saving trained model to models/pret_transE-ep-03.dyn
# 2022-04-29 04:58:39.669508	starting epoch 4
# 2022-04-29 04:58:39.669594	starting loop over has_part
# 100% 41105/41105 [06:18<00:00, 108.46it/s]
# 2022-04-29 05:04:58.660689	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:16<00:00, 159.96it/s]
# 2022-04-29 05:09:15.635867	starting loop over member_of_domain_region
# 100% 41105/41105 [01:26<00:00, 473.85it/s]
# 2022-04-29 05:10:42.389491	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:02<00:00, 657.58it/s]
# 2022-04-29 05:11:44.904007	starting loop over similar_to
# 2022-04-29 05:11:44.904041	RELATION OVERRIDEN
# 2022-04-29 05:11:44.904053	starting loop over member_meronym
# 100% 41105/41105 [09:40<00:00, 70.77it/s]
# 2022-04-29 05:21:25.755766	starting loop over derivationally_related_form
# 2022-04-29 05:21:25.755793	RELATION OVERRIDEN
# 2022-04-29 05:21:25.755812	starting loop over instance_hypernym
# 100% 41105/41105 [03:55<00:00, 174.36it/s]
# 2022-04-29 05:25:21.506039	starting loop over hypernym
# 100% 41105/41105 [43:17<00:00, 15.83it/s]
# 2022-04-29 06:08:38.724834	starting loop over also_see
# 2022-04-29 06:08:38.724863	RELATION OVERRIDEN
# 2022-04-29 06:08:38.724872	starting loop over verb_group
# 2022-04-29 06:08:38.724880	RELATION OVERRIDEN
# 2022-04-29 06:08:38.725960	evaluating after epoch 4
# 2022-04-29 06:17:16.689982	mrr: 0.4243, h@10: 0.4919, h@1: 0.3917
# 2022-04-29 06:17:16.690135	saving trained model to models/pret_transE-ep-04.dyn
# 2022-04-29 06:17:44.277860	starting epoch 5
# 2022-04-29 06:17:44.277978	starting loop over member_meronym
# 100% 41105/41105 [09:19<00:00, 73.41it/s]
# 2022-04-29 06:27:04.228184	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:09<00:00, 164.61it/s]
# 2022-04-29 06:31:13.942132	starting loop over derivationally_related_form
# 100% 41105/41105 [38:44<00:00, 17.68it/s]
# 2022-04-29 07:09:58.677044	starting loop over has_part
# 100% 41105/41105 [06:34<00:00, 104.28it/s]
# 2022-04-29 07:16:32.876292	starting loop over member_of_domain_region
# 100% 41105/41105 [01:28<00:00, 463.79it/s]
# 2022-04-29 07:18:01.508967	starting loop over also_see
# 100% 41105/41105 [01:57<00:00, 350.99it/s]
# 2022-04-29 07:19:58.624200	starting loop over hypernym
# 100% 41105/41105 [44:18<00:00, 15.46it/s]
# 2022-04-29 08:04:17.220317	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:08<00:00, 603.06it/s]
# 2022-04-29 08:05:25.393590	starting loop over verb_group
# 100% 41105/41105 [01:51<00:00, 370.31it/s]
# 2022-04-29 08:07:16.402650	starting loop over similar_to
# 100% 41105/41105 [00:22<00:00, 1837.02it/s]
# 2022-04-29 08:07:38.783898	starting loop over instance_hypernym
# 100% 41105/41105 [04:08<00:00, 165.26it/s]
# 2022-04-29 08:11:47.526790	evaluating after epoch 5
# 2022-04-29 08:20:36.438045	mrr: 0.4254, h@10: 0.4959, h@1: 0.3926
# 2022-04-29 08:20:36.438183	saving trained model to models/pret_transE-ep-05.dyn
# 2022-04-29 08:21:01.448326	starting epoch 6
# 2022-04-29 08:21:01.448441	starting loop over member_of_domain_region
# 100% 41105/41105 [01:23<00:00, 490.92it/s]
# 2022-04-29 08:22:25.182984	starting loop over derivationally_related_form
# 2022-04-29 08:22:25.183006	RELATION OVERRIDEN
# 2022-04-29 08:22:25.183023	starting loop over similar_to
# 2022-04-29 08:22:25.183056	RELATION OVERRIDEN
# 2022-04-29 08:22:25.183072	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:25<00:00, 155.02it/s]
# 2022-04-29 08:26:50.344124	starting loop over hypernym
# 100% 41105/41105 [45:53<00:00, 14.93it/s]
# 2022-04-29 09:12:43.466181	starting loop over member_meronym
# 100% 41105/41105 [09:59<00:00, 68.61it/s]
# 2022-04-29 09:22:42.559631	starting loop over has_part
# 100% 41105/41105 [06:37<00:00, 103.34it/s]
# 2022-04-29 09:29:20.326741	starting loop over verb_group
# 2022-04-29 09:29:20.326765	RELATION OVERRIDEN
# 2022-04-29 09:29:20.326775	starting loop over also_see
# 2022-04-29 09:29:20.326795	RELATION OVERRIDEN
# 2022-04-29 09:29:20.326807	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:05<00:00, 625.28it/s]
# 2022-04-29 09:30:26.072040	starting loop over instance_hypernym
# 100% 41105/41105 [04:06<00:00, 167.08it/s]
# 2022-04-29 09:34:32.103859	evaluating after epoch 6
# 2022-04-29 09:43:30.268067	mrr: 0.4260, h@10: 0.4980, h@1: 0.3934
# 2022-04-29 09:43:30.268233	saving trained model to models/pret_transE-ep-06.dyn
# 2022-04-29 09:43:57.446916	starting epoch 7
# 2022-04-29 09:43:57.447022	starting loop over hypernym
# 100% 41105/41105 [43:37<00:00, 15.70it/s]
# 2022-04-29 10:27:35.215815	starting loop over similar_to
# 2022-04-29 10:27:35.215838	RELATION OVERRIDEN
# 2022-04-29 10:27:35.215850	starting loop over has_part
# 100% 41105/41105 [07:07<00:00, 96.18it/s]
# 2022-04-29 10:34:42.592709	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:31<00:00, 151.68it/s]
# 2022-04-29 10:39:13.598962	starting loop over also_see
# 2022-04-29 10:39:13.598982	RELATION OVERRIDEN
# 2022-04-29 10:39:13.599001	starting loop over member_of_domain_region
# 100% 41105/41105 [01:33<00:00, 437.58it/s]
# 2022-04-29 10:40:47.542051	starting loop over member_meronym
# 100% 41105/41105 [10:25<00:00, 65.74it/s]
# 2022-04-29 10:51:12.807450	starting loop over derivationally_related_form
# 2022-04-29 10:51:12.807470	RELATION OVERRIDEN
# 2022-04-29 10:51:12.807498	starting loop over verb_group
# 2022-04-29 10:51:12.807515	RELATION OVERRIDEN
# 2022-04-29 10:51:12.807523	starting loop over instance_hypernym
# 100% 41105/41105 [04:10<00:00, 164.11it/s]
# 2022-04-29 10:55:23.289533	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:02<00:00, 659.02it/s]
# 2022-04-29 10:56:25.668343	evaluating after epoch 7
# 2022-04-29 11:05:34.637078	mrr: 0.4268, h@10: 0.5000, h@1: 0.3939
# 2022-04-29 11:05:34.637259	saving trained model to models/pret_transE-ep-07.dyn
# 2022-04-29 11:06:10.365868	starting epoch 8
# 2022-04-29 11:06:10.365987	starting loop over member_meronym
# 100% 41105/41105 [10:08<00:00, 67.58it/s]
# 2022-04-29 11:16:18.640226	starting loop over instance_hypernym
# 100% 41105/41105 [04:14<00:00, 161.75it/s]
# 2022-04-29 11:20:32.768351	starting loop over derivationally_related_form
# 2022-04-29 11:20:32.768379	RELATION OVERRIDEN
# 2022-04-29 11:20:32.768392	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:08<00:00, 603.17it/s]
# 2022-04-29 11:21:40.922169	starting loop over similar_to
# 2022-04-29 11:21:40.922232	RELATION OVERRIDEN
# 2022-04-29 11:21:40.922258	starting loop over verb_group
# 2022-04-29 11:21:40.922270	RELATION OVERRIDEN
# 2022-04-29 11:21:40.922286	starting loop over hypernym
# 100% 41105/41105 [47:33<00:00, 14.41it/s]
# 2022-04-29 12:09:13.971716	starting loop over member_of_domain_region
# 100% 41105/41105 [01:32<00:00, 446.69it/s]
# 2022-04-29 12:10:45.997779	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:32<00:00, 150.58it/s]
# 2022-04-29 12:15:18.973938	starting loop over has_part
# 100% 41105/41105 [07:17<00:00, 93.87it/s]
# 2022-04-29 12:22:36.860054	starting loop over also_see
# 2022-04-29 12:22:36.860088	RELATION OVERRIDEN
# 2022-04-29 12:22:36.861310	evaluating after epoch 8
# 2022-04-29 12:32:14.953603	mrr: 0.4272, h@10: 0.5007, h@1: 0.3940
# 2022-04-29 12:32:14.953802	saving trained model to models/pret_transE-ep-08.dyn
# 2022-04-29 12:32:46.943056	starting epoch 9
# 2022-04-29 12:32:46.943187	starting loop over instance_hypernym
# 100% 41105/41105 [04:08<00:00, 165.47it/s]
# 2022-04-29 12:36:55.365635	starting loop over has_part
# 100% 41105/41105 [07:17<00:00, 93.91it/s]
# 2022-04-29 12:44:13.087375	starting loop over hypernym
# 100% 41105/41105 [47:28<00:00, 14.43it/s]
# 2022-04-29 13:31:41.925778	starting loop over derivationally_related_form
# 2022-04-29 13:31:41.925846	RELATION OVERRIDEN
# 2022-04-29 13:31:41.925867	starting loop over member_of_domain_region
# 100% 41105/41105 [01:34<00:00, 435.77it/s]
# 2022-04-29 13:33:16.257464	starting loop over member_meronym
# 100% 41105/41105 [10:43<00:00, 63.89it/s]
# 2022-04-29 13:43:59.665506	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:35<00:00, 149.20it/s]
# 2022-04-29 13:48:35.174150	starting loop over also_see
# 2022-04-29 13:48:35.174180	RELATION OVERRIDEN
# 2022-04-29 13:48:35.174195	starting loop over similar_to
# 2022-04-29 13:48:35.174223	RELATION OVERRIDEN
# 2022-04-29 13:48:35.174238	starting loop over verb_group
# 2022-04-29 13:48:35.174251	RELATION OVERRIDEN
# 2022-04-29 13:48:35.174265	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:07<00:00, 612.30it/s]
# 2022-04-29 13:49:42.312824	evaluating after epoch 9
# 2022-04-29 13:59:16.571525	mrr: 0.4274, h@10: 0.5000, h@1: 0.3939
# 2022-04-29 13:59:16.571685	saving trained model to models/pret_transE-ep-09.dyn
# 2022-04-29 13:59:47.551904	starting epoch 10
# 2022-04-29 13:59:47.552001	starting loop over verb_group
# 100% 41105/41105 [01:48<00:00, 379.97it/s]
# 2022-04-29 14:01:35.738386	starting loop over member_meronym
# 100% 41105/41105 [10:39<00:00, 64.29it/s]
# 2022-04-29 14:12:15.136831	starting loop over has_part
# 100% 41105/41105 [06:46<00:00, 101.23it/s]
# 2022-04-29 14:19:01.178876	starting loop over member_of_domain_region
# 100% 41105/41105 [01:27<00:00, 472.11it/s]
# 2022-04-29 14:20:28.251555	starting loop over hypernym
# 100% 41105/41105 [46:33<00:00, 14.71it/s]
# 2022-04-29 15:07:02.184828	starting loop over derivationally_related_form
# 100% 41105/41105 [41:32<00:00, 16.49it/s]
# 2022-04-29 15:48:34.788795	starting loop over instance_hypernym
# 100% 41105/41105 [04:12<00:00, 162.83it/s]
# 2022-04-29 15:52:47.233149	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:27<00:00, 153.63it/s]
# 2022-04-29 15:57:14.802033	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:07<00:00, 609.71it/s]
# 2022-04-29 15:58:22.225420	starting loop over similar_to
# 100% 41105/41105 [00:22<00:00, 1805.92it/s]
# 2022-04-29 15:58:44.991742	starting loop over also_see
# 100% 41105/41105 [02:10<00:00, 315.06it/s]
# 2022-04-29 16:00:55.464253	evaluating after epoch 10
# 2022-04-29 16:10:19.777389	mrr: 0.4285, h@10: 0.5002, h@1: 0.3945
# 2022-04-29 16:10:19.777653	saving trained model to models/pret_transE-ep-10.dyn
# 2022-04-29 16:10:48.880302	starting epoch 11
# 2022-04-29 16:10:48.880402	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:27<00:00, 153.54it/s]
# 2022-04-29 16:15:16.603764	starting loop over similar_to
# 2022-04-29 16:15:16.603794	RELATION OVERRIDEN
# 2022-04-29 16:15:16.603805	starting loop over member_of_domain_region
# 100% 41105/41105 [01:31<00:00, 447.58it/s]
# 2022-04-29 16:16:48.446932	starting loop over derivationally_related_form
# 2022-04-29 16:16:48.446965	RELATION OVERRIDEN
# 2022-04-29 16:16:48.446977	starting loop over verb_group
# 2022-04-29 16:16:48.446990	RELATION OVERRIDEN
# 2022-04-29 16:16:48.446997	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:07<00:00, 610.58it/s]
# 2022-04-29 16:17:55.772914	starting loop over hypernym
# 100% 41105/41105 [47:15<00:00, 14.50it/s]
# 2022-04-29 17:05:10.924197	starting loop over also_see
# 2022-04-29 17:05:10.924232	RELATION OVERRIDEN
# 2022-04-29 17:05:10.924241	starting loop over instance_hypernym
# 100% 41105/41105 [04:20<00:00, 157.99it/s]
# 2022-04-29 17:09:31.107217	starting loop over member_meronym
# 100% 41105/41105 [10:46<00:00, 63.58it/s]
# 2022-04-29 17:20:17.647239	starting loop over has_part
# 100% 41105/41105 [07:04<00:00, 96.75it/s]
# 2022-04-29 17:27:22.525427	evaluating after epoch 11
# 2022-04-29 17:37:27.096121	mrr: 0.4287, h@10: 0.5012, h@1: 0.3947
# 2022-04-29 17:37:27.096327	saving trained model to models/pret_transE-ep-11.dyn
# 2022-04-29 17:37:55.998033	starting epoch 12
# 2022-04-29 17:37:55.998173	starting loop over verb_group
# 2022-04-29 17:37:55.998200	RELATION OVERRIDEN
# 2022-04-29 17:37:55.998233	starting loop over similar_to
# 2022-04-29 17:37:55.998258	RELATION OVERRIDEN
# 2022-04-29 17:37:55.998266	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:20<00:00, 157.95it/s]
# 2022-04-29 17:42:16.245598	starting loop over member_meronym
# 100% 41105/41105 [10:29<00:00, 65.30it/s]
# 2022-04-29 17:52:45.728861	starting loop over also_see
# 2022-04-29 17:52:45.728888	RELATION OVERRIDEN
# 2022-04-29 17:52:45.728896	starting loop over instance_hypernym
# 100% 41105/41105 [04:11<00:00, 163.28it/s]
# 2022-04-29 17:56:57.478125	starting loop over member_of_domain_region
# 100% 41105/41105 [01:29<00:00, 457.28it/s]
# 2022-04-29 17:58:27.372526	starting loop over derivationally_related_form
# 2022-04-29 17:58:27.372552	RELATION OVERRIDEN
# 2022-04-29 17:58:27.372570	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:05<00:00, 626.24it/s]
# 2022-04-29 17:59:33.015985	starting loop over has_part
# 100% 41105/41105 [07:02<00:00, 97.37it/s]
# 2022-04-29 18:06:35.159949	starting loop over hypernym
# 100% 41105/41105 [47:45<00:00, 14.34it/s]
# 2022-04-29 18:54:20.749400	evaluating after epoch 12
# 2022-04-29 19:03:49.663997	mrr: 0.4289, h@10: 0.5012, h@1: 0.3947
# 2022-04-29 19:03:49.664159	saving trained model to models/pret_transE-ep-12.dyn
# 2022-04-29 19:04:20.767477	starting epoch 13
# 2022-04-29 19:04:20.767664	starting loop over derivationally_related_form
# 2022-04-29 19:04:20.767684	RELATION OVERRIDEN
# 2022-04-29 19:04:20.767692	starting loop over similar_to
# 2022-04-29 19:04:20.767700	RELATION OVERRIDEN
# 2022-04-29 19:04:20.767707	starting loop over instance_hypernym
# 100% 41105/41105 [04:11<00:00, 163.66it/s]
# 2022-04-29 19:08:31.931249	starting loop over member_meronym
# 100% 41105/41105 [10:45<00:00, 63.64it/s]
# 2022-04-29 19:19:17.815734	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:09<00:00, 590.90it/s]
# 2022-04-29 19:20:27.384747	starting loop over also_see
# 2022-04-29 19:20:27.384784	RELATION OVERRIDEN
# 2022-04-29 19:20:27.384801	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:41<00:00, 145.89it/s]
# 2022-04-29 19:25:09.145608	starting loop over verb_group
# 2022-04-29 19:25:09.145635	RELATION OVERRIDEN
# 2022-04-29 19:25:09.145647	starting loop over has_part
# 100% 41105/41105 [07:12<00:00, 95.12it/s]
# 2022-04-29 19:32:21.292338	starting loop over member_of_domain_region
# 100% 41105/41105 [01:34<00:00, 436.37it/s]
# 2022-04-29 19:33:55.496159	starting loop over hypernym
# 100% 41105/41105 [47:04<00:00, 14.55it/s]
# 2022-04-29 20:20:59.996807	evaluating after epoch 13
# 2022-04-29 20:30:25.146690	mrr: 0.4290, h@10: 0.5016, h@1: 0.3942
# 2022-04-29 20:30:25.146875	saving trained model to models/pret_transE-ep-13.dyn
# 2022-04-29 20:30:55.487436	starting epoch 14
# 2022-04-29 20:30:55.487625	starting loop over also_see
# 2022-04-29 20:30:55.487774	RELATION OVERRIDEN
# 2022-04-29 20:30:55.487783	starting loop over hypernym
# 100% 41105/41105 [46:47<00:00, 14.64it/s]
# 2022-04-29 21:17:43.391144	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:45<00:00, 144.02it/s]
# 2022-04-29 21:22:28.812631	starting loop over derivationally_related_form
# 2022-04-29 21:22:28.812661	RELATION OVERRIDEN
# 2022-04-29 21:22:28.812695	starting loop over similar_to
# 2022-04-29 21:22:28.812709	RELATION OVERRIDEN
# 2022-04-29 21:22:28.812733	starting loop over verb_group
# 2022-04-29 21:22:28.812749	RELATION OVERRIDEN
# 2022-04-29 21:22:28.812767	starting loop over instance_hypernym
# 100% 41105/41105 [04:27<00:00, 153.75it/s]
# 2022-04-29 21:26:56.167462	starting loop over member_of_domain_region
# 100% 41105/41105 [01:34<00:00, 435.65it/s]
# 2022-04-29 21:28:30.527072	starting loop over has_part
# 100% 41105/41105 [07:14<00:00, 94.59it/s]
# 2022-04-29 21:35:45.071107	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:10<00:00, 584.80it/s]
# 2022-04-29 21:36:55.364917	starting loop over member_meronym
#  51% 21090/41105 [05:45<09:57, 33.47it/s]
