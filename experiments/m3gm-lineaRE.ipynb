# %%
# !sudo add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !sudo apt-get update -qq 2>&1 > /dev/null
# !sudo apt -y install -qq google-drive-ocamlfuse 2>&1 > /dev/null
# !google-drive-ocamlfuse
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=xrWpR5Yl%2FusLh3fEjF9J5VBE0u547k%2FKAxLb48ZBPAU'
# /bin/sh: 1: firefox: not found
# /bin/sh: 1: google-chrome: not found
# /bin/sh: 1: chromium-browser: not found
# /bin/sh: 1: open: not found
# Cannot retrieve auth tokens.
# Failure("Error opening URL:https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=xrWpR5Yl%2FusLh3fEjF9J5VBE0u547k%2FKAxLb48ZBPAU")

# %%
# !sudo apt-get install -qq w3m # to act as web browser 
# !xdg-settings set default-web-browser w3m.desktop # to set default browser
# %cd /content
# !mkdir drive
# %cd drive
# !mkdir MyDrive
# %cd ..
# %cd ..
# !google-drive-ocamlfuse /content/drive/MyDrive
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgpm2:amd64.
# (Reading database ... 155519 files and directories currently installed.)
# Preparing to unpack .../libgpm2_1.20.7-5_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.7-5) ...
# Selecting previously unselected package w3m.
# Preparing to unpack .../w3m_0.5.3-36build1_amd64.deb ...
# Unpacking w3m (0.5.3-36build1) ...
# Setting up libgpm2:amd64 (1.20.7-5) ...
# Setting up w3m (0.5.3-36build1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# /content
# /content/drive
# /content
# /
# Access token retrieved correctly.

# %% [markdown]
# ## Dependencies

# %%
# !pip install dynet
# !pip show dynet
# Out:
# Collecting dynet
#   Downloading dyNET-2.1.2-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 5.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dynet) (1.21.6)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from dynet) (0.29.28)
# Installing collected packages: dynet
# Successfully installed dynet-2.1.2
# Name: dyNET
# Version: 2.1.2
# Summary: The Dynamic Neural Network Toolkit
# Home-page: https://github.com/clab/dynet
# Author: Graham Neubig
# Author-email: dynet-users@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: numpy, cython
# Required-by:

# %%
# %cd /content/drive/MyDrive/10708/m3gm-master
# !python create_wn18_data.py --base-dir /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text
# Out:
# /content/drive/MyDrive/10708/m3gm-master
# read 86834 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/train.txt, now have 40714 synsets
# read 3033 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/valid.txt, now have 40919 synsets
# read 3133 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/test.txt, now have 41105 synsets
# all relations:  {'member_meronym', 'derivationally_related_form', 'synset_domain_topic_of', 'has_part', 'also_see', 'member_of_domain_region', 'instance_hypernym', 'similar_to', 'verb_group', 'hypernym', 'member_of_domain_usage'}
# node count:  41105
# first sorted synsets:  ['land_reform.n.01', 'reform.n.01', 'cover.v.01', 'covering.n.02', 'botany.n.02', 'botanize.v.01', 'kamet.n.01', 'mountain_peak.n.01', 'question.n.01', 'ask.v.01']
# last sorted synsets:  ['fire.v.06', 'parade.n.03', 'grey_matter.n.01', 'clinton.n.02', 'hamstring.v.01', 'holly-leaved_cherry.n.01', 'warwick.n.01', 'iconoclast.n.01', 'electrocution.n.01', 'accentor.n.01']
# creating matrices for relations in train set
# created matrix for relation member_meronym
# sample: portunidae.n.01->['swimming_crab.n.01', 'callinectes.n.01', 'ovalipes.n.01', 'portunus.n.01']
# created matrix for relation derivationally_related_form
# sample: confiscation.n.01->['assume.v.06', 'impound.v.01']
# created matrix for relation synset_domain_topic_of
# sample: federal_bureau_of_investigation.n.01->['law.n.01']
# created matrix for relation has_part
# sample: brassiere.n.01->['strap.n.03']
# created matrix for relation also_see
# sample: short.a.03->['low.a.02']
# created matrix for relation member_of_domain_region
# sample: malaysia.n.01->['godown.n.01', 'jemaah_islamiyah.n.01', "al-ma'unah.n.01"]
# created matrix for relation instance_hypernym
# sample: mongolia.n.01->['asian_country.n.01']
# created matrix for relation similar_to
# sample: cosignatory.s.01->['joint.a.01']
# created matrix for relation verb_group
# sample: bite.v.02->['burn.v.10']
# created matrix for relation hypernym
# sample: bignonia.n.01->['asterid_dicot_genus.n.01']
# created matrix for relation member_of_domain_usage
# sample: abbreviation.n.01->['appro.n.01']
# creating matrices for relations in dev set
# created matrix for relation member_meronym
# sample: aphriza.n.01->['surfbird.n.01']
# created matrix for relation derivationally_related_form
# sample: ridicule.v.01->['satirist.n.01']
# created matrix for relation synset_domain_topic_of
# sample: battle_damage.n.01->['military.n.01']
# created matrix for relation has_part
# sample: airplane.n.01->['accelerator.n.01']
# created matrix for relation also_see
# sample: unproductive.a.01->['sterile.a.01']
# created matrix for relation member_of_domain_region
# sample: france.n.01->['first_estate.n.01']
# created matrix for relation instance_hypernym
# sample: mark.n.08->['evangelist.n.02']
# created matrix for relation similar_to
# sample: senior.a.01->['major.s.08']
# created matrix for relation verb_group
# sample: die.v.01->['fail.v.04']
# created matrix for relation hypernym
# sample: common_pond-skater.n.01->['water_strider.n.01']
# created matrix for relation member_of_domain_usage
# sample: colloquialism.n.01->['plague.n.05', 'long_johns.n.01']
# creating matrices for relations in test set
# created matrix for relation member_meronym
# sample: felis.n.01->['cougar.n.01']
# created matrix for relation derivationally_related_form
# sample: synchronize.v.02->['synchronism.n.01']
# created matrix for relation synset_domain_topic_of
# sample: right_to_vote.n.01->['law.n.01']
# created matrix for relation has_part
# sample: immune_system.n.01->['marrow.n.01']
# created matrix for relation also_see
# sample: squeeze.v.02->['extrude.v.01']
# created matrix for relation member_of_domain_region
# sample: new_zealand.n.01->['returning_officer.n.01']
# created matrix for relation instance_hypernym
# sample: nan_ling.n.01->['range.n.04']
# created matrix for relation similar_to
# sample: colored.a.01->['cream-colored.s.01']
# created matrix for relation verb_group
# sample: exclaim.v.01->['call_out.v.02']
# created matrix for relation hypernym
# sample: population.n.01->['people.n.01']
# created matrix for relation member_of_domain_usage
# sample: trope.n.01->['dawn.n.03', 'cakewalk.n.02']
# saving dataset
# done!

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# %cd /content/drive/MyDrive/10708/m3gm-master/data
# !python embed_from_words.py wiki-news-300d-1M.vec ft-embs-all-lower.vec
# Out:
# 2022-03-13 19:20:50.184081	read 117659 synsets
# 2022-03-13 19:20:50.184156	preparing target word dataset
# 100% 117659/117659 [00:00<00:00, 483892.35it/s]
# 2022-03-13 19:20:50.429026	reading input file
# tcmalloc: large alloc 2259091456 bytes == 0x5564e0408000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db54ed17 0x5564db6ce1f5 0x5564db6688f8 0x5564db5525d2 0x5564db63197e 0x5564db552229 0x5564db644b3d 0x5564db5c6458 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 2259091456 bytes == 0x556566e78000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db599b6c 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 4518182912 bytes == 0x5565ed8e8000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db59b9e6 0x5564db59b6c8 0x5564db5a8bdf 0x5564db59a1eb 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 9036357632 bytes == 0x5566fb5c8000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db59b945 0x5564db59b6c8 0x5564db5a8bdf 0x5564db59a1eb 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# ^C

# %%
# !python pretrain_assoc.py --input data/sparse_wn18_matrices.pkl --embeddings data/ft-embs-all-lower.vec --model-out models/pret_lineaRE --nll --assoc-mode lineaRE --neg-samp 10 --early-stopping --eval-dev
# Out:
# [dynet] random seed: 3042281473
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# 2022-04-27 16:50:39.589394	graphs file = data/sparse_wn18_matrices.pkl
# 2022-04-27 16:50:39.589458	embeddings file = data/ft-embs-all-lower.vec
# 2022-04-27 16:50:39.589471	association mode = lineaRE
# 2022-04-27 16:50:39.589488	negative samples = 10
# 2022-04-27 16:50:39.589502	model file = models/pret_lineaRE
# 2022-04-27 16:50:39.589516	using negative log likelihood loss
# 2022-04-27 16:50:39.589530	employing early stopping (over last 2 epochs)
# 2022-04-27 16:50:39.589547	dropout = 0.0
# 2022-04-27 16:50:39.589561	max epochs = 20
# 2022-04-27 16:50:39.589578	Adagrad learning rate = 0.01
# 2022-04-27 16:50:39.589594	rand-nodes = True
# 2022-04-27 16:50:39.589608	overriding symmetric relations with rule-based system
# 2022-04-27 16:50:39.589618	evaluating dev set
# 2022-04-27 16:50:39.633244	loading embeddings...
# 2022-04-27 16:50:54.508677	finished initialization for association model.
# 2022-04-27 16:50:55.299868	starting epoch 1
# 2022-04-27 16:50:55.300024	starting loop over synset_domain_topic_of
#   0% 0/41105 [00:00<?, ?it/s]The dy.parameter(...) call is now DEPRECATED.
#         There is no longer need to explicitly add parameters to the computation graph.
#         Any used parameter will be added automatically.
# 100% 41105/41105 [04:39<00:00, 147.15it/s]
# 2022-04-27 16:55:34.653613	starting loop over verb_group
# 2022-04-27 16:55:34.653632	RELATION OVERRIDEN
# 2022-04-27 16:55:34.653639	starting loop over hypernym
# 100% 41105/41105 [44:43<00:00, 15.32it/s]
# 2022-04-27 17:40:18.542396	starting loop over member_of_domain_region
# 100% 41105/41105 [01:27<00:00, 468.73it/s]
# 2022-04-27 17:41:46.239675	starting loop over member_meronym
# 100% 41105/41105 [09:34<00:00, 71.58it/s]
# 2022-04-27 17:51:20.522384	starting loop over instance_hypernym
# 100% 41105/41105 [04:02<00:00, 169.44it/s]
# 2022-04-27 17:55:23.122655	starting loop over similar_to
# 2022-04-27 17:55:23.122684	RELATION OVERRIDEN
# 2022-04-27 17:55:23.122698	starting loop over has_part
# 100% 41105/41105 [06:16<00:00, 109.20it/s]
# 2022-04-27 18:01:39.534734	starting loop over derivationally_related_form
# 2022-04-27 18:01:39.534773	RELATION OVERRIDEN
# 2022-04-27 18:01:39.534794	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:02<00:00, 660.34it/s]
# 2022-04-27 18:02:41.786632	starting loop over also_see
# 2022-04-27 18:02:41.786653	RELATION OVERRIDEN
# 2022-04-27 18:02:41.787746	evaluating after epoch 1
# 2022-04-27 18:12:37.925125	mrr: 0.3673, h@10: 0.3909, h@1: 0.3556
# 2022-04-27 18:12:37.925334	saving trained model to models/pret_lineaRE-ep-01.dyn
# 2022-04-27 18:13:03.606127	starting epoch 2
# 2022-04-27 18:13:03.606249	starting loop over verb_group
# 2022-04-27 18:13:03.606272	RELATION OVERRIDEN
# 2022-04-27 18:13:03.606291	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:02<00:00, 659.74it/s]
# 2022-04-27 18:14:05.914505	starting loop over also_see
# 2022-04-27 18:14:05.914527	RELATION OVERRIDEN
# 2022-04-27 18:14:05.914546	starting loop over similar_to
# 2022-04-27 18:14:05.914553	RELATION OVERRIDEN
# 2022-04-27 18:14:05.914563	starting loop over instance_hypernym
# 100% 41105/41105 [03:53<00:00, 175.79it/s]
# 2022-04-27 18:17:59.753184	starting loop over member_of_domain_region
# 100% 41105/41105 [01:26<00:00, 473.10it/s]
# 2022-04-27 18:19:26.640865	starting loop over has_part
# 100% 41105/41105 [06:55<00:00, 98.83it/s]
# 2022-04-27 18:26:22.565715	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:35<00:00, 149.13it/s]
# 2022-04-27 18:30:58.204548	starting loop over derivationally_related_form
# 2022-04-27 18:30:58.204570	RELATION OVERRIDEN
# 2022-04-27 18:30:58.204578	starting loop over hypernym
# 100% 41105/41105 [43:18<00:00, 15.82it/s]
# 2022-04-27 19:14:16.401180	starting loop over member_meronym
# 100% 41105/41105 [09:21<00:00, 73.17it/s]
# 2022-04-27 19:23:38.201051	evaluating after epoch 2
# 2022-04-27 19:33:41.496135	mrr: 0.3690, h@10: 0.3921, h@1: 0.3570
# 2022-04-27 19:33:41.496313	saving trained model to models/pret_lineaRE-ep-02.dyn
# 2022-04-27 19:34:05.446197	starting epoch 3
# 2022-04-27 19:34:05.446309	starting loop over similar_to
# 2022-04-27 19:34:05.446326	RELATION OVERRIDEN
# 2022-04-27 19:34:05.446334	starting loop over has_part
# 100% 41105/41105 [06:13<00:00, 109.96it/s]
# 2022-04-27 19:40:19.270759	starting loop over member_meronym
# 100% 41105/41105 [09:22<00:00, 73.02it/s]
# 2022-04-27 19:49:42.181847	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:10<00:00, 163.91it/s]
# 2022-04-27 19:53:52.969513	starting loop over instance_hypernym
# 100% 41105/41105 [03:58<00:00, 172.54it/s]
# 2022-04-27 19:57:51.212236	starting loop over verb_group
# 2022-04-27 19:57:51.212258	RELATION OVERRIDEN
# 2022-04-27 19:57:51.212296	starting loop over derivationally_related_form
# 2022-04-27 19:57:51.212312	RELATION OVERRIDEN
# 2022-04-27 19:57:51.212319	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:02<00:00, 660.06it/s]
# 2022-04-27 19:58:53.492025	starting loop over also_see
# 2022-04-27 19:58:53.492056	RELATION OVERRIDEN
# 2022-04-27 19:58:53.492079	starting loop over member_of_domain_region
# 100% 41105/41105 [01:27<00:00, 467.80it/s]
# 2022-04-27 20:00:21.364900	starting loop over hypernym
# 100% 41105/41105 [45:46<00:00, 14.96it/s]
# 2022-04-27 20:46:08.142120	evaluating after epoch 3
# 2022-04-27 20:56:26.084837	mrr: 0.3681, h@10: 0.3909, h@1: 0.3546
# 2022-04-27 20:56:26.084947	starting epoch 4
# 2022-04-27 20:56:26.085023	starting loop over derivationally_related_form
# 2022-04-27 20:56:26.085039	RELATION OVERRIDEN
# 2022-04-27 20:56:26.085046	starting loop over has_part
# 100% 41105/41105 [06:19<00:00, 108.38it/s]
# 2022-04-27 21:02:45.339585	starting loop over member_meronym
# 100% 41105/41105 [09:17<00:00, 73.70it/s]
# 2022-04-27 21:12:03.053218	starting loop over similar_to
# 2022-04-27 21:12:03.053238	RELATION OVERRIDEN
# 2022-04-27 21:12:03.053249	starting loop over verb_group
# 2022-04-27 21:12:03.053278	RELATION OVERRIDEN
# 2022-04-27 21:12:03.053286	starting loop over hypernym
# 100% 41105/41105 [42:57<00:00, 15.95it/s]
# 2022-04-27 21:55:00.620878	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:04<00:00, 168.38it/s]
# 2022-04-27 21:59:04.750291	starting loop over member_of_domain_region
# 100% 41105/41105 [01:23<00:00, 492.12it/s]
# 2022-04-27 22:00:28.280708	starting loop over instance_hypernym
# 100% 41105/41105 [03:50<00:00, 178.35it/s]
# 2022-04-27 22:04:18.758257	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:01<00:00, 669.86it/s]
# 2022-04-27 22:05:20.125626	starting loop over also_see
# 2022-04-27 22:05:20.125651	RELATION OVERRIDEN
# 2022-04-27 22:05:20.126760	evaluating after epoch 4
# 2022-04-27 22:15:43.322039	mrr: 0.3685, h@10: 0.3940, h@1: 0.3548
# 2022-04-27 22:15:43.322129	starting epoch 5
# 2022-04-27 22:15:43.322194	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:01<00:00, 669.48it/s]
# 2022-04-27 22:16:44.724099	starting loop over also_see
# 100% 41105/41105 [01:54<00:00, 358.16it/s]
# 2022-04-27 22:18:39.496036	starting loop over verb_group
# 100% 41105/41105 [01:56<00:00, 351.48it/s]
# 2022-04-27 22:20:36.449934	starting loop over has_part
# 100% 41105/41105 [07:14<00:00, 94.56it/s]
# 2022-04-27 22:27:51.149827	starting loop over member_of_domain_region
# 100% 41105/41105 [01:31<00:00, 447.17it/s]
# 2022-04-27 22:29:23.078895	starting loop over instance_hypernym
# 100% 41105/41105 [04:15<00:00, 160.93it/s]
# 2022-04-27 22:33:38.502361	starting loop over similar_to
# 100% 41105/41105 [00:25<00:00, 1644.12it/s]
# 2022-04-27 22:34:03.508745	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:39<00:00, 146.85it/s]
# 2022-04-27 22:38:43.432876	starting loop over hypernym
# 100% 41105/41105 [44:28<00:00, 15.41it/s]
# 2022-04-27 23:23:11.486285	starting loop over member_meronym
# 100% 41105/41105 [09:34<00:00, 71.53it/s]
# 2022-04-27 23:32:46.158291	starting loop over derivationally_related_form
# 100% 41105/41105 [39:20<00:00, 17.42it/s]
# 2022-04-28 00:12:06.404507	evaluating after epoch 5
# 2022-04-28 00:20:55.785235	mrr: 0.3696, h@10: 0.3935, h@1: 0.3566
# 2022-04-28 00:20:55.785391	saving trained model to models/pret_lineaRE-ep-05.dyn
# 2022-04-28 00:21:25.369843	starting epoch 6
# 2022-04-28 00:21:25.370081	starting loop over hypernym
# 100% 41105/41105 [42:45<00:00, 16.02it/s]
# 2022-04-28 01:04:11.003153	starting loop over member_meronym
# 100% 41105/41105 [10:00<00:00, 68.49it/s]
# 2022-04-28 01:14:11.143292	starting loop over derivationally_related_form
# 2022-04-28 01:14:11.143313	RELATION OVERRIDEN
# 2022-04-28 01:14:11.143324	starting loop over has_part
# 100% 41105/41105 [06:19<00:00, 108.30it/s]
# 2022-04-28 01:20:30.706387	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:09<00:00, 165.01it/s]
# 2022-04-28 01:24:39.808561	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:02<00:00, 660.21it/s]
# 2022-04-28 01:25:42.073952	starting loop over member_of_domain_region
# 100% 41105/41105 [01:24<00:00, 486.24it/s]
# 2022-04-28 01:27:06.615849	starting loop over similar_to
# 2022-04-28 01:27:06.615871	RELATION OVERRIDEN
# 2022-04-28 01:27:06.615886	starting loop over verb_group
# 2022-04-28 01:27:06.615893	RELATION OVERRIDEN
# 2022-04-28 01:27:06.615903	starting loop over instance_hypernym
# 100% 41105/41105 [03:55<00:00, 174.80it/s]
# 2022-04-28 01:31:01.769182	starting loop over also_see
# 2022-04-28 01:31:01.769242	RELATION OVERRIDEN
# 2022-04-28 01:31:01.770321	evaluating after epoch 6
# 2022-04-28 01:39:34.883002	mrr: 0.3709, h@10: 0.3935, h@1: 0.3583
# 2022-04-28 01:39:34.883225	saving trained model to models/pret_lineaRE-ep-06.dyn
# 2022-04-28 01:40:01.904525	starting epoch 7
# 2022-04-28 01:40:01.904646	starting loop over has_part
# 100% 41105/41105 [06:13<00:00, 110.20it/s]
# 2022-04-28 01:46:14.917321	starting loop over also_see
# 2022-04-28 01:46:14.917352	RELATION OVERRIDEN
# 2022-04-28 01:46:14.917374	starting loop over instance_hypernym
# 100% 41105/41105 [03:56<00:00, 173.73it/s]
# 2022-04-28 01:50:11.530861	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:05<00:00, 632.30it/s]
# 2022-04-28 01:51:16.544063	starting loop over verb_group
# 2022-04-28 01:51:16.544158	RELATION OVERRIDEN
# 2022-04-28 01:51:16.544175	starting loop over similar_to
# 2022-04-28 01:51:16.544182	RELATION OVERRIDEN
# 2022-04-28 01:51:16.544189	starting loop over derivationally_related_form
# 2022-04-28 01:51:16.544195	RELATION OVERRIDEN
# 2022-04-28 01:51:16.544201	starting loop over member_meronym
# 100% 41105/41105 [10:05<00:00, 67.88it/s]
# 2022-04-28 02:01:22.115059	starting loop over member_of_domain_region
# 100% 41105/41105 [01:39<00:00, 415.19it/s]
# 2022-04-28 02:03:01.122256	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:12<00:00, 162.55it/s]
# 2022-04-28 02:07:14.007129	starting loop over hypernym
# 100% 41105/41105 [43:00<00:00, 15.93it/s]
# 2022-04-28 02:50:14.786107	evaluating after epoch 7
# 2022-04-28 02:59:13.480724	mrr: 0.3704, h@10: 0.3940, h@1: 0.3576
# 2022-04-28 02:59:13.480813	starting epoch 8
# 2022-04-28 02:59:13.480888	starting loop over similar_to
# 2022-04-28 02:59:13.480901	RELATION OVERRIDEN
# 2022-04-28 02:59:13.480910	starting loop over verb_group
# 2022-04-28 02:59:13.480929	RELATION OVERRIDEN
# 2022-04-28 02:59:13.480939	starting loop over instance_hypernym
# 100% 41105/41105 [03:53<00:00, 176.08it/s]
# 2022-04-28 03:03:06.924739	starting loop over hypernym
# 100% 41105/41105 [42:51<00:00, 15.98it/s]
# 2022-04-28 03:45:58.813141	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:02<00:00, 660.42it/s]
# 2022-04-28 03:47:01.057204	starting loop over also_see
# 2022-04-28 03:47:01.057259	RELATION OVERRIDEN
# 2022-04-28 03:47:01.057277	starting loop over member_meronym
# 100% 41105/41105 [09:29<00:00, 72.18it/s]
# 2022-04-28 03:56:30.511840	starting loop over derivationally_related_form
# 2022-04-28 03:56:30.511858	RELATION OVERRIDEN
# 2022-04-28 03:56:30.511876	starting loop over member_of_domain_region
# 100% 41105/41105 [01:25<00:00, 482.65it/s]
# 2022-04-28 03:57:55.680343	starting loop over has_part
# 100% 41105/41105 [06:17<00:00, 108.80it/s]
# 2022-04-28 04:04:13.504333	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:09<00:00, 165.00it/s]
# 2022-04-28 04:08:22.633548	evaluating after epoch 8
# 2022-04-28 04:16:58.626741	mrr: 0.3705, h@10: 0.3937, h@1: 0.3583
# 2022-04-28 04:16:58.626819	starting epoch 9
# 2022-04-28 04:16:58.626862	starting loop over hypernym
# 100% 41105/41105 [44:19<00:00, 15.46it/s]
# 2022-04-28 05:01:18.151230	starting loop over also_see
# 2022-04-28 05:01:18.151259	RELATION OVERRIDEN
# 2022-04-28 05:01:18.151268	starting loop over derivationally_related_form
# 2022-04-28 05:01:18.151277	RELATION OVERRIDEN
# 2022-04-28 05:01:18.151285	starting loop over has_part
# 100% 41105/41105 [06:25<00:00, 106.72it/s]
# 2022-04-28 05:07:43.314262	starting loop over instance_hypernym
# 100% 41105/41105 [03:56<00:00, 173.47it/s]
# 2022-04-28 05:11:40.278630	starting loop over synset_domain_topic_of
# 100% 41105/41105 [04:11<00:00, 163.43it/s]
# 2022-04-28 05:15:51.791134	starting loop over member_of_domain_region
# 100% 41105/41105 [01:25<00:00, 481.71it/s]
# 2022-04-28 05:17:17.126673	starting loop over member_meronym
# 100% 41105/41105 [09:30<00:00, 72.10it/s]
# 2022-04-28 05:26:47.220825	starting loop over similar_to
# 2022-04-28 05:26:47.220849	RELATION OVERRIDEN
# 2022-04-28 05:26:47.220857	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:02<00:00, 660.65it/s]
# 2022-04-28 05:27:49.443473	starting loop over verb_group
# 2022-04-28 05:27:49.443493	RELATION OVERRIDEN
# 2022-04-28 05:27:49.444817	evaluating after epoch 9
# 2022-04-28 05:36:27.619878	mrr: 0.3699, h@10: 0.3945, h@1: 0.3573
# training losses: 199572.35800170898	165799.03540420532	154754.18040847778	147435.29927825928	270704.7168006897	138231.16024780273	134665.22271347046	131872.82078170776	129466.57773590088
# number of instances: 6068
# average rank: 7561.440177982861
# mrr: 0.3709
# mq: 0.8160412568610631
# h@100: 0.45221
# h@10: 0.39354
# h@1: 0.35827
