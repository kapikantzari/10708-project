# %%
# !sudo add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !sudo apt-get update -qq 2>&1 > /dev/null
# !sudo apt -y install -qq google-drive-ocamlfuse 2>&1 > /dev/null
# !google-drive-ocamlfuse
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# ...

# %%
# !sudo apt-get install -qq w3m # to act as web browser 
# !xdg-settings set default-web-browser w3m.desktop # to set default browser
# %cd /content
# !mkdir drive
# %cd drive
# !mkdir MyDrive
# %cd ..
# %cd ..
# !google-drive-ocamlfuse /content/drive/MyDrive
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgpm2:amd64.
# (Reading database ... 155519 files and directories currently installed.)
# Preparing to unpack .../libgpm2_1.20.7-5_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.7-5) ...
# Selecting previously unselected package w3m.
# Preparing to unpack .../w3m_0.5.3-36build1_amd64.deb ...
# Unpacking w3m (0.5.3-36build1) ...
# Setting up libgpm2:amd64 (1.20.7-5) ...
# Setting up w3m (0.5.3-36build1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# ...

# %% [markdown]
# ## Dependencies

# %%
# !pip install dynet
# !pip show dynet
# Out:
# ...
#      |████████████████████████████████| 4.4 MB 4.1 MB/s
# ...
# Name: dyNET
# Version: 2.1.2
# Summary: The Dynamic Neural Network Toolkit
# Home-page: https://github.com/clab/dynet
# Author: Graham Neubig
# Author-email: dynet-users@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: cython, numpy
# Required-by:

# %%
# %cd /content/drive/MyDrive/10708/m3gm-master
# !python create_wn18_data.py --base-dir /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text
# Out:
# /content/drive/MyDrive/10708/m3gm-master
# read 86834 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/train.txt, now have 40714 synsets
# read 3033 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/valid.txt, now have 40919 synsets
# read 3133 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/test.txt, now have 41105 synsets
# all relations:  {'synset_domain_topic_of', 'member_of_domain_usage', 'hypernym', 'has_part', 'member_of_domain_region', 'derivationally_related_form', 'also_see', 'instance_hypernym', 'verb_group', 'member_meronym', 'similar_to'}
# node count:  41105
# first sorted synsets:  ['land_reform.n.01', 'reform.n.01', 'cover.v.01', 'covering.n.02', 'botany.n.02', 'botanize.v.01', 'kamet.n.01', 'mountain_peak.n.01', 'question.n.01', 'ask.v.01']
# ...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# %cd /content/drive/MyDrive/10708/m3gm-master/data
# !python embed_from_words.py wiki-news-300d-1M.vec ft-embs-all-lower.vec
# Out:
# 2022-03-13 19:20:50.184081	read 117659 synsets
# 2022-03-13 19:20:50.184156	preparing target word dataset
# 100% 117659/117659 [00:00<00:00, 483892.35it/s]
# 2022-03-13 19:20:50.429026	reading input file
# tcmalloc: large alloc 2259091456 bytes == 0x5564e0408000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db54ed17 0x5564db6ce1f5 0x5564db6688f8 0x5564db5525d2 0x5564db63197e 0x5564db552229 0x5564db644b3d 0x5564db5c6458 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# ...

# %%
# !python pretrain_assoc.py --input data/sparse_wn18_matrices.pkl --embeddings data/ft-embs-all-lower.vec --model-out models/pret_sE --nll --assoc-mode sE --neg-samp 10 --early-stopping --eval-dev
# Out:
# [dynet] random seed: 3394021713
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# 2022-04-27 01:50:02.137136	graphs file = data/sparse_wn18_matrices.pkl
# 2022-04-27 01:50:02.137206	embeddings file = data/ft-embs-all-lower.vec
# 2022-04-27 01:50:02.137217	association mode = sE
# 2022-04-27 01:50:02.137226	negative samples = 10
# 2022-04-27 01:50:02.137234	model file = models/pret_sE
# 2022-04-27 01:50:02.137241	using negative log likelihood loss
# 2022-04-27 01:50:02.137249	employing early stopping (over last 2 epochs)
# 2022-04-27 01:50:02.137260	dropout = 0.0
# 2022-04-27 01:50:02.137268	max epochs = 20
# 2022-04-27 01:50:02.137278	Adagrad learning rate = 0.01
# 2022-04-27 01:50:02.137288	rand-nodes = True
# 2022-04-27 01:50:02.137296	overriding symmetric relations with rule-based system
# 2022-04-27 01:50:02.137303	evaluating dev set
# 2022-04-27 01:50:05.724323	loading embeddings...
# 2022-04-27 01:50:31.389106	finished initialization for association model.
# ...

# %%
# !python pretrain_assoc.py --input data/sparse_wn18_matrices.pkl --embeddings data/ft-embs-all-lower.vec --model models/pret_sE-ep-06 --model-out models/pret_sE --nll --assoc-mode sE --neg-samp 10 --early-stopping --eval-dev
# Out:
# [dynet] random seed: 3715552817
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# 2022-04-27 20:07:55.281160	graphs file = data/sparse_wn18_matrices.pkl
# 2022-04-27 20:07:55.281227	embeddings file = data/ft-embs-all-lower.vec
# 2022-04-27 20:07:55.281237	association mode = sE
# 2022-04-27 20:07:55.281245	negative samples = 10
# 2022-04-27 20:07:55.281251	test mode only
# 2022-04-27 20:07:55.281258	model file = models/pret_sE-ep-06
# 2022-04-27 20:07:55.281270	overriding symmetric relations with rule-based system
# 2022-04-27 20:07:55.281284	evaluating dev set
# 2022-04-27 20:08:00.207131	loading embeddings...
# 2022-04-27 20:08:10.521960	loading association model from file: models/pret_sE-ep-06
# 2022-04-27 20:08:18.801351	finished initialization for association model.
# 2022-04-27 20:08:20.730105	starting epoch 7
# 2022-04-27 20:08:20.730220	starting loop over synset_domain_topic_of
#   0% 0/41105 [00:00<?, ?it/s]The dy.parameter(...) call is now DEPRECATED.
# ...
