# %%
# !sudo add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !sudo apt-get update -qq 2>&1 > /dev/null
# !sudo apt -y install -qq google-drive-ocamlfuse 2>&1 > /dev/null
# !google-drive-ocamlfuse
# Out:
# W: GPG error: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY A4B469963BF863CC
# E: The repository 'https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease' is no longer signed.
# W: GPG error: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY A4B469963BF863CC
# E: The repository 'https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease' is no longer signed.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=jJSrAKgygELg20yvI2lsNZhO8fRZsJct8p8TvtCpByM'
# /bin/sh: 1: firefox: not found
# /bin/sh: 1: google-chrome: not found
# /bin/sh: 1: chromium-browser: not found
# /bin/sh: 1: open: not found
# Cannot retrieve auth tokens.
# Failure("Error opening URL:https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=jJSrAKgygELg20yvI2lsNZhO8fRZsJct8p8TvtCpByM")

# %%
# !sudo apt-get install -qq w3m # to act as web browser 
# !xdg-settings set default-web-browser w3m.desktop # to set default browser
# %cd /content
# !mkdir drive
# %cd drive
# !mkdir MyDrive
# %cd ..
# %cd ..
# !google-drive-ocamlfuse /content/drive/MyDrive
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgpm2:amd64.
# (Reading database ... 155519 files and directories currently installed.)
# Preparing to unpack .../libgpm2_1.20.7-5_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.7-5) ...
# Selecting previously unselected package w3m.
# Preparing to unpack .../w3m_0.5.3-36build1_amd64.deb ...
# Unpacking w3m (0.5.3-36build1) ...
# Setting up libgpm2:amd64 (1.20.7-5) ...
# Setting up w3m (0.5.3-36build1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# /content
# /content/drive
# /content
# /
# Access token retrieved correctly.

# %% [markdown]
# ## Dependencies

# %%
# !pip install dynet
# !pip show dynet
# Out:
# Collecting dynet
#   Downloading dyNET-2.1.2-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 5.1 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from dynet) (0.29.28)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dynet) (1.21.6)
# Installing collected packages: dynet
# Successfully installed dynet-2.1.2
# Name: dyNET
# Version: 2.1.2
# Summary: The Dynamic Neural Network Toolkit
# Home-page: https://github.com/clab/dynet
# Author: Graham Neubig
# Author-email: dynet-users@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: numpy, cython
# Required-by:

# %%
# %cd /content/drive/MyDrive/10708/m3gm-master
# !python create_wn18_data.py --base-dir /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text
# Out:
# /content/drive/MyDrive/10708/m3gm-master
# read 86834 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/train.txt, now have 40714 synsets
# read 3033 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/valid.txt, now have 40919 synsets
# read 3133 instances with 11 relations from /content/drive/MyDrive/10708/datasets_knowledge_embedding-master/WN18RR/text/test.txt, now have 41105 synsets
# all relations:  {'similar_to', 'hypernym', 'member_meronym', 'instance_hypernym', 'synset_domain_topic_of', 'member_of_domain_region', 'member_of_domain_usage', 'verb_group', 'also_see', 'derivationally_related_form', 'has_part'}
# node count:  41105
# first sorted synsets:  ['land_reform.n.01', 'reform.n.01', 'cover.v.01', 'covering.n.02', 'botany.n.02', 'botanize.v.01', 'kamet.n.01', 'mountain_peak.n.01', 'question.n.01', 'ask.v.01']
# last sorted synsets:  ['fire.v.06', 'parade.n.03', 'grey_matter.n.01', 'clinton.n.02', 'hamstring.v.01', 'holly-leaved_cherry.n.01', 'warwick.n.01', 'iconoclast.n.01', 'electrocution.n.01', 'accentor.n.01']
# creating matrices for relations in train set
# created matrix for relation similar_to
# sample: can-do.s.01->['dynamic.a.01']
# created matrix for relation hypernym
# sample: chicory.n.02->['herb.n.01']
# created matrix for relation member_meronym
# sample: droseraceae.n.01->['drosophyllum.n.01', 'drosera.n.01', 'aldrovanda.n.01', 'dionaea.n.01']
# created matrix for relation instance_hypernym
# sample: pamir_mountains.n.01->['range.n.04']
# created matrix for relation synset_domain_topic_of
# sample: revolutionary_organization_17_november.n.01->['terrorism.n.01']
# created matrix for relation member_of_domain_region
# sample: philippines.n.02->['bataan.n.01', 'leyte.n.01']
# created matrix for relation member_of_domain_usage
# sample: plural.n.01->['military_quarters.n.01', 'tights.n.01', 'stations.n.01', 'interest.n.06', 'ambages.n.01', 'operations.n.01', 'irons.n.01', 'exercise.n.05', 'authority.n.02', 'spectacles.n.01', 'nerves.n.02', 'greeting.n.01', 'brass_knucks.n.01', 'breeches.n.01', 'heroics.n.01', 'appointment.n.03', 'people.n.01', 'craps.n.02', 'shears.n.01', 'white_goods.n.01', 'furnishing.n.02', 'jodhpurs.n.01', 'badlands.n.01', 'ummah.n.01', 'headquarters.n.03', 'writing.n.03', 'fedayeen.n.01', 'bloomers.n.01', 'telecommunication.n.01', 'confines.n.01', 'paring.n.02', 'relation.n.06', 'drawers.n.01', 'liabilities.n.01', 'flannel.n.03', 'goggles.n.01', 'cafeteria_facility.n.01', 'tongs.n.01', 'bifocals.n.01', 'spoil.n.01', 'binoculars.n.01', 'headquarters.n.02', 'arts_and_crafts.n.01', 'deliberation.n.01', 'seven_wonders_of_the_ancient_world.n.01', 'togs.n.01', 'basic.n.02', 'channel.n.05', 'assets.n.01', 'plus_fours.n.01', 'fixings.n.02', 'rudiment.n.01', 'footlights.n.01', 'scablands.n.01', 'flinders.n.02', 'fire_tongs.n.01', 'scissors.n.01', 'pliers.n.01', 'devotion.n.04', 'augean_stables.n.01', 'fatigues.n.01', 'gallows.n.01', 'hustings.n.01', 'boxcars.n.01', 'hiccup.n.01', 'bedspring.n.01', 'regard.n.03', 'bones.n.01', 'underpants.n.01', 'secateurs.n.01', 'dregs.n.01', 'epsom_salts.n.02', 'suspension_point.n.01', 'overtone.n.01', 'sweat_pants.n.01', 'folks.n.01', 'jean.n.01', 'liquid_assets.n.01', 'living_quarters.n.01', 'dirty_tricks.n.01', 'bare_bones.n.01', 'durables.n.01', 'sporting_goods.n.01', 'order.n.01', 'buckskins.n.01', 'jinks.n.01', 'yard_goods.n.01', 'stairs.n.01', 'bellbottom_trousers.n.01', 'pantie.n.01', 'drygoods.n.01', 'street_clothes.n.01', 'congratulation.n.02', 'telecommunication.n.02', 'calisthenics.n.02', 'parallel_bars.n.01', 'headquarters.n.01', 'firework.n.01', 'innings.n.01', 'stocking.n.01', 'bermuda_shorts.n.01', 'grocery.n.02', 'regimentals.n.01', 'consumer_goods.n.01', 'furnishing.n.01', 'right.n.08', 'ravage.n.01', 'chain_tongs.n.01', 'civies.n.01', 'remains.n.01', 'oat.n.02', 'manners.n.01', 'public_works.n.01', 'contretemps.n.01']
# created matrix for relation verb_group
# sample: desorb.v.02->['desorb.v.01']
# created matrix for relation also_see
# sample: contented.a.01->['happy.a.01']
# created matrix for relation derivationally_related_form
# sample: formalism.n.02->['formalistic.a.01']
# created matrix for relation has_part
# sample: government.n.01->['judiciary.n.02', 'administration.n.02']
# creating matrices for relations in dev set
# created matrix for relation similar_to
# sample: incomparable.a.01->['alone.s.04']
# created matrix for relation hypernym
# sample: data_structure.n.01->['arrangement.n.03']
# created matrix for relation member_meronym
# sample: acocanthera.n.01->["bushman's_poison.n.01"]
# created matrix for relation instance_hypernym
# sample: sombrero.n.01->['island.n.01']
# created matrix for relation synset_domain_topic_of
# sample: average.n.02->['sport.n.01']
# created matrix for relation member_of_domain_region
# sample: soviet_union.n.01->['kvass.n.01', 'stern.n.02']
# created matrix for relation member_of_domain_usage
# sample: colloquialism.n.01->['plague.n.05', 'long_johns.n.01']
# created matrix for relation verb_group
# sample: pop.v.13->['pop.v.12']
# created matrix for relation also_see
# sample: ask.v.02->['invite.v.02']
# created matrix for relation derivationally_related_form
# sample: ridicule.v.01->['satirist.n.01']
# created matrix for relation has_part
# sample: alabama.n.01->['alabama.n.03']
# creating matrices for relations in test set
# created matrix for relation similar_to
# sample: dynamic.a.01->['can-do.s.01']
# created matrix for relation hypernym
# sample: animate.v.04->['stimulate.v.04']
# created matrix for relation member_meronym
# sample: bignonia.n.01->['cross_vine.n.01']
# created matrix for relation instance_hypernym
# sample: tirich_mir.n.01->['mountain_peak.n.01']
# created matrix for relation synset_domain_topic_of
# sample: army_officer.n.01->['military.n.01']
# created matrix for relation member_of_domain_region
# sample: greece.n.01->['sibyl.n.02', 'cacodemon.n.01']
# created matrix for relation member_of_domain_usage
# sample: trade_name.n.01->['metharbital.n.01', 'diazepam.n.01', 'verapamil.n.01', 'cling_film.n.01', 'isoniazid.n.01', 'meclizine.n.01', 'propanolol.n.01', 'digoxin.n.01', 'rifampin.n.01', 'clomiphene.n.01']
# created matrix for relation verb_group
# sample: oxidize.v.02->['oxidise.v.02']
# created matrix for relation also_see
# sample: uncreative.a.01->['unoriginal.a.01']
# created matrix for relation derivationally_related_form
# sample: deformation.n.02->['deform.v.04']
# created matrix for relation has_part
# sample: immune_system.n.01->['marrow.n.01']
# saving dataset
# done!

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# %cd /content/drive/MyDrive/10708/m3gm-master/data
# !python embed_from_words.py wiki-news-300d-1M.vec ft-embs-all-lower.vec
# Out:
# 2022-03-13 19:20:50.184081	read 117659 synsets
# 2022-03-13 19:20:50.184156	preparing target word dataset
# 100% 117659/117659 [00:00<00:00, 483892.35it/s]
# 2022-03-13 19:20:50.429026	reading input file
# tcmalloc: large alloc 2259091456 bytes == 0x5564e0408000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db54ed17 0x5564db6ce1f5 0x5564db6688f8 0x5564db5525d2 0x5564db63197e 0x5564db552229 0x5564db644b3d 0x5564db5c6458 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 2259091456 bytes == 0x556566e78000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db599b6c 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 4518182912 bytes == 0x5565ed8e8000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db59b9e6 0x5564db59b6c8 0x5564db5a8bdf 0x5564db59a1eb 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# tcmalloc: large alloc 9036357632 bytes == 0x5566fb5c8000 @  0x7f8aee4e41e7 0x5564db584518 0x5564db59b945 0x5564db59b6c8 0x5564db5a8bdf 0x5564db59a1eb 0x5564db627b5b 0x5564db552229 0x5564db552120 0x5564db5c6679 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db553aba 0x5564db5c62c0 0x5564db5c102f 0x5564db5c0d43 0x5564db68b302 0x5564db68b67d 0x5564db68b526 0x5564db6631d3 0x5564db662e7c 0x7f8aed2cec87 0x5564db662d5a
# ^C

# %%
# !python pretrain_assoc.py --input data/sparse_wn18_matrices.pkl --embeddings data/ft-embs-all-lower.vec --model-out models/pret_quatDE --nll --assoc-mode quatDE --neg-samp 10 --early-stopping --eval-dev
# Out:
# [dynet] random seed: 920536477
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# 2022-04-29 16:25:04.129621	graphs file = data/sparse_wn18_matrices.pkl
# 2022-04-29 16:25:04.129703	embeddings file = data/ft-embs-all-lower.vec
# 2022-04-29 16:25:04.129750	association mode = quatDE
# 2022-04-29 16:25:04.129772	negative samples = 10
# 2022-04-29 16:25:04.129788	model file = models/pret_quatDE
# 2022-04-29 16:25:04.129802	using negative log likelihood loss
# 2022-04-29 16:25:04.129816	employing early stopping (over last 2 epochs)
# 2022-04-29 16:25:04.129834	dropout = 0.0
# 2022-04-29 16:25:04.129851	max epochs = 20
# 2022-04-29 16:25:04.129869	Adagrad learning rate = 0.01
# 2022-04-29 16:25:04.129886	rand-nodes = True
# 2022-04-29 16:25:04.129901	overriding symmetric relations with rule-based system
# 2022-04-29 16:25:04.129923	evaluating dev set
# 2022-04-29 16:25:04.215807	loading embeddings...
# 2022-04-29 16:25:18.481504	finished initialization for association model.
# 2022-04-29 16:25:19.292977	starting epoch 1
# 2022-04-29 16:25:19.293129	starting loop over also_see
# 2022-04-29 16:25:19.293160	RELATION OVERRIDEN
# 2022-04-29 16:25:19.293173	starting loop over hypernym
# 100% 41105/41105 [1:35:10<00:00,  7.20it/s]
# 2022-04-29 18:00:29.878799	starting loop over instance_hypernym
# 100% 41105/41105 [08:00<00:00, 85.48it/s]
# 2022-04-29 18:08:30.784913	starting loop over verb_group
# 2022-04-29 18:08:30.784935	RELATION OVERRIDEN
# 2022-04-29 18:08:30.784953	starting loop over member_meronym
# 100% 41105/41105 [21:48<00:00, 31.42it/s]
# 2022-04-29 18:30:18.915741	starting loop over has_part
# 100% 41105/41105 [14:08<00:00, 48.46it/s]
# 2022-04-29 18:44:27.119881	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:52<00:00, 366.02it/s]
# 2022-04-29 18:46:19.429988	starting loop over synset_domain_topic_of
# 100% 41105/41105 [08:37<00:00, 79.44it/s]
# 2022-04-29 18:54:56.861982	starting loop over similar_to
# 2022-04-29 18:54:56.862002	RELATION OVERRIDEN
# 2022-04-29 18:54:56.862026	starting loop over member_of_domain_region
# 100% 41105/41105 [02:44<00:00, 250.46it/s]
# 2022-04-29 18:57:40.987560	starting loop over derivationally_related_form
# 2022-04-29 18:57:40.987585	RELATION OVERRIDEN
# 2022-04-29 18:57:40.988855	evaluating after epoch 1
# 2022-04-29 19:06:19.634817	mrr: 0.3524, h@10: 0.3523, h@1: 0.3523
# 2022-04-29 19:06:19.634908	saving trained model to models/pret_quatDE-ep-01.dyn
# 2022-04-29 19:07:36.053352	starting epoch 2
# 2022-04-29 19:07:36.053476	starting loop over instance_hypernym
# 100% 41105/41105 [07:41<00:00, 88.99it/s]
# 2022-04-29 19:15:17.983332	starting loop over member_of_domain_region
# 100% 41105/41105 [02:44<00:00, 249.58it/s]
# 2022-04-29 19:18:02.692872	starting loop over member_of_domain_usage
# 100% 41105/41105 [01:52<00:00, 366.87it/s]
# 2022-04-29 19:19:54.740394	starting loop over derivationally_related_form
# 2022-04-29 19:19:54.740417	RELATION OVERRIDEN
# 2022-04-29 19:19:54.740426	starting loop over verb_group
# 2022-04-29 19:19:54.740432	RELATION OVERRIDEN
# 2022-04-29 19:19:54.740440	starting loop over similar_to
# 2022-04-29 19:19:54.740449	RELATION OVERRIDEN
# 2022-04-29 19:19:54.740459	starting loop over also_see
# 2022-04-29 19:19:54.740468	RELATION OVERRIDEN
# 2022-04-29 19:19:54.740477	starting loop over synset_domain_topic_of
# 100% 41105/41105 [08:36<00:00, 79.64it/s]
# 2022-04-29 19:28:30.858619	starting loop over member_meronym
# 100% 41105/41105 [22:50<00:00, 30.00it/s]
# 2022-04-29 19:51:20.975073	starting loop over hypernym
# 100% 41105/41105 [1:38:32<00:00,  6.95it/s]
# 2022-04-29 21:29:53.166721	starting loop over has_part
#  95% 38855/41105 [12:47<00:52, 43.07it/s]
